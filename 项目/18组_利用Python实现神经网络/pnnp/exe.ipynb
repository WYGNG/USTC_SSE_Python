# %%
import NeuralNetwork as nn
import main

# %%
main.convertFile()

# %%
net=nn.FNN(784,10,64,64,0.1)

# %%
main.train(net,"data/train_60000.csv")
# Out:
# 训练开始！！！
# 训练完毕！！！

# %%
main.test(net,"data/test_10000.csv")
# Out:
# 测试开始！！！
# 正确个数： 9128  错误个数： 872
# 测试结束！！！

# %%
main.testSmall(net)

# %%
nn.write(net,"net/64_64_0.1_91.28%")

# %%
net2=nn.copy("net/64_64_0.1_91.28%")

# %%
main.testSmall(net2)
